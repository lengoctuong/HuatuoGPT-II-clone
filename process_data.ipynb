# %%
#%%
import os
os.environ["TMPDIR"] = "./tmp"
os.makedirs("./tmp", exist_ok=True)
import copy
import json
import os
import torch
import logging
import argparse
from transformers.generation.utils import LogitsProcessorList
from transformers.generation.logits_process import LogitsProcessor

from tqdm import tqdm
import torch.distributed as dist
from torch.utils.data import Dataset, DataLoader, Sampler
import wandb
import transformers
from typing import Sequence
import datasets
import shutil
import json
import random


from transformers import AutoModelForCausalLM, AutoTokenizer, AutoModel

took_qa_pos = []
took_index = []
sampled_ids = set()

class WeightedRandomSampler(Sampler[int]):
    def __init__(self, weights: Sequence[float], num_samples: int,
                 replacement: bool = False, manual_seed=2147483647) -> None:
        if not isinstance(num_samples, int) or isinstance(num_samples, bool) or \
                num_samples <= 0 or num_samples > len(weights):
            raise ValueError("num_samples should be a positive integer "
                             "value less than or equal to len(weights), but got num_samples={}".format(num_samples))
        if not isinstance(replacement, bool):
            raise ValueError("replacement should be a boolean value, but got "
                             "replacement={}".format(replacement))
        global sampled_ids
        self.weights = torch.as_tensor(weights, dtype=torch.double)
        self.num_samples = num_samples
        self.replacement = False
        self.generator = torch.Generator()
        self.generator.manual_seed(manual_seed)
        self.rand_list = torch.multinomial(self.weights, self.weights.shape[0], self.replacement, generator=self.generator).tolist()
        self.pos = 0
        self.sampled_ids = sampled_ids
        print('weights', list(self.weights))

    def __iter__(self):
        while self.pos < self.num_samples:
            idx = self.rand_list[self.pos]
            self.pos += 1
            self.sampled_ids.add(idx)
            took_qa_pos.append(idx)
            yield idx

    def __len__(self) -> int:
        return self.num_samples

    def update_dynamic_weight(self, new_weights: Sequence[float]):
        if len(new_weights) != len(self.weights):
            raise ValueError("Length of new_weights must match the current weights")

        self.weights = torch.as_tensor(new_weights, dtype=torch.double)

        available_indices = list(set(range(len(self.weights))) - self.sampled_ids)
        available_weights = [self.weights[i] for i in available_indices]

        # Resample taking into account already sampled ids
        new_samples = torch.multinomial(torch.as_tensor(available_weights), len(available_indices), self.replacement, generator=self.generator)
        new_list = [available_indices[i] for i in new_samples.tolist()]
        self.pos = len(self.sampled_ids)
        self.rand_list[self.pos:] = new_list
        assert len(self.rand_list) == len(new_weights)

class HuatuoGPT_data(torch.utils.data.Dataset):
    def __init__(self, config, tokenizer, debug=False):
        self.config = config
        self.tokenizer = tokenizer
        with open(config.data_path) as f:
            self.data_dict = json.load(f)
        self.datacollatorforseq2seq = transformers.DataCollatorForSeq2Seq(tokenizer, return_tensors="pt", padding=True)
        self.ignore_index = -100
        self.sep = '\n'
        self.sep_ids = self.tokenizer.encode(self.sep,add_special_tokens= False)
        self.roles = ('<问>：','<答>：')
        self.ignore_len = len(self.tokenizer.encode(self.sep + self.roles[1],add_special_tokens= False))
        self.debug = debug

        self.lengths = {k: len(self.data_dict[k]) for k in self.data_dict.keys()}
        self.keys = list(self.data_dict.keys())
        
        # you need to set
        # When you want random sampling, please set the same data priority
        self.data_priority = {'Meidcal_Web_Corpus_en': 32,
                              'Meidcal_Web_Corpus_cn': 32,
                            'Meidcal_Literature_cn': 16,
                            'Meidcal_Literature_en': 16,
                            'Meidcal_Encyclopedia_cn':8,
                            'Meidcal_Encyclopedia_en':8,
                            'Meidcal_Books_cn': 4,
                            'Meidcal_Books_en': 4,
                            'SFT_data': 1}
        
        self.data_epoch = {'Meidcal_Web_Corpus_en': 1,
                              'Meidcal_Web_Corpus_cn': 1,
                            'Meidcal_Literature_cn': 1,
                            'Meidcal_Literature_en': 1,
                            'Meidcal_Encyclopedia_cn': 1,
                            'Meidcal_Encyclopedia_en': 1,
                            'Meidcal_Books_cn': 1,
                            'Meidcal_Books_en': 1,
                            'SFT_data': 3}

        self.weights = []
        self.pos_key = []

        for keyi,key in enumerate(self.keys):
            priority = self.data_priority[key]
            epoch = self.data_epoch[key]
            self.weights += [priority] * int(self.lengths[key]*epoch)
            self.pos_key += [keyi] * int(self.lengths[key]*epoch)

    
    def __getitem__(self, index):
        key = self.keys[self.pos_key[index]]
        sub_index = index % self.lengths[key]
        took_index.append((index, key))
        da = self.preprocess(self.data_dict[key][sub_index])
        da['data_type'] = key
        return da

    def get_data_info(self):
        res = {}
        total = 0
        for k,v in self.data_epoch.items():
            res[k] = self.lengths[k]*v
            total += self.lengths[k]*v
        res['sum'] = total
        return res

    def preprocess(self, data):
        input_ids = []
        labels = []
        if not isinstance(data, list):
            raise ValueError('The data must be a list.')
        for ind, d in enumerate(data):
            if ind % 2 == 1:
                value_ids = self.tokenizer.encode(self.sep + self.roles[1] + d,add_special_tokens= False, max_length=self.config.max_seq_len, truncation=True)
                input_ids += value_ids
                labels += [self.ignore_index] *self.ignore_len + value_ids[self.ignore_len:]
                if len(labels) >= self.config.max_seq_len:
                    if self.debug:
                        print('break max len', len(labels))
                    break
            else:
                pre_str = self.sep if len(input_ids) > 0 else ''
                value_ids = self.tokenizer.encode(pre_str + self.roles[0] + d,add_special_tokens= False, max_length=self.config.max_seq_len, truncation=True)
                input_ids += value_ids

                if len(labels) > 0:
                    labels += [self.tokenizer.eos_token_id] + [self.ignore_index] * (len(value_ids)-1)
                else:
                    labels += [self.ignore_index] * len(value_ids)
        if self.debug and len(data) != 2:
            print('data len more than 2', len(data), len(input_ids))
        input_ids.append(self.tokenizer.eos_token_id)
        labels.append(self.tokenizer.eos_token_id)
        if self.debug:
            print('input_ids',self.tokenizer.decode(input_ids))
            labels = [item if item != self.ignore_index else self.tokenizer.pad_token_id for item in labels]
            # print('labels',self.tokenizer.convert_ids_to_tokens(labels))
            print('labels',self.tokenizer.decode(labels))
            self.debug = False
        if self.debug:
            print('len after preprocess', len(input_ids), len(labels))
        return {'input_ids': input_ids[:self.config.max_seq_len], 'labels': labels[:self.config.max_seq_len]}

    def __len__(self):
        return len(self.weights)

    def sample_num(self):
        return len(self.weights)

    def collate_fn(self, batch):
        return batch
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
parser = argparse.ArgumentParser(description='Args of Data Preprocess')
debug = False

class Args:
    def __init__(self, data_path="/mnt/c/Users/HOME/Downloads/HuatuoGPT-II/adaption/one_stage_training/train_qa_1p.json",
                 model_path="baichuan-inc/Baichuan2-13B-Base",
                 max_seq_len=4096):
        self.data_path = data_path
        self.model_path = model_path
        self.max_seq_len = max_seq_len

args = Args()

args.train_bsz_per_gpu = 32
args.save_path = '.'.join(os.path.split(args.data_path)[-1].split('.')[:-1])+'_'+os.path.split(args.model_path)[-1]+f'_{args.max_seq_len}_dataset'
print(f'The dataset will save in {args.save_path}')
tokenizer = AutoTokenizer.from_pretrained(args.model_path, trust_remote_code=True, use_fast=True)
if tokenizer.pad_token is None:
    tokenizer.pad_token = '<PAD>'

#%%
train_dataset = HuatuoGPT_data(args, tokenizer)

sampler = WeightedRandomSampler(train_dataset.weights, num_samples=train_dataset.sample_num(), replacement=False)
train_dataloader = DataLoader(train_dataset, batch_size=args.train_bsz_per_gpu, sampler=sampler, drop_last=False, collate_fn=train_dataset.collate_fn)

train_dataloader_iterator = tqdm(enumerate(train_dataloader))
args.log_step = len(train_dataloader) // 10

from collections import defaultdict
key_nums = defaultdict(int)
args.experiment_name = 'huatuo2_datapre'

wandb.init(project = args.experiment_name, config=args, dir= os.path.join('./train_logs',args.experiment_name))

all_inputs_ids = []
all_labels = []
pad_id = tokenizer.pad_token_id
ignore_index = -100
for batch_cnt, batch in train_dataloader_iterator:
    cur_input = []
    cur_label = []

    for i, da in enumerate(batch):
        key_nums[da['data_type']] += 1
        if len(da['input_ids']) + len(cur_input) <= args.max_seq_len:
            cur_input += da['input_ids']
            cur_label +=  da['labels']
        else:
            if debug:
                print('appended len', len(cur_input), len(cur_label), 'batch', batch_cnt, 'index', i)
            pad_len = args.max_seq_len - len(cur_input)
            cur_input += [pad_id] * pad_len
            cur_label += [ignore_index] * pad_len
            all_inputs_ids.append(cur_input)
            all_labels.append(cur_label)
            cur_input = da['input_ids']
            cur_label =  da['labels']
    if debug:
        print('appended len', len(cur_input), len(cur_label), 'batch', batch_cnt)
    pad_len = args.max_seq_len - len(cur_input)
    cur_input += [pad_id] * pad_len
    cur_label += [ignore_index] * pad_len
    all_inputs_ids.append(cur_input)
    all_labels.append(cur_label)
    assert len(cur_input) == len(cur_label) == args.max_seq_len, f'{len(cur_input)},{len(cur_label)}'

    if batch_cnt % args.log_step == 0:
        logdata = {}
        for key in key_nums:
            logdata[key + '_num'] = key_nums[key]
            if debug:
                print('log', key, key_nums[key])
        wandb.log(logdata)
        key_nums = defaultdict(int)

assert len(all_inputs_ids) == len(all_labels)
print('all_inputs_ids len', len(all_inputs_ids))
save_dataset = datasets.Dataset.from_dict({'input_ids': all_inputs_ids, 'labels':all_labels})
save_dataset.save_to_disk(args.save_path)

table = wandb.Table(columns=["data_priority", "data_epoch","data_num"])
table.add_data(json.dumps(train_dataset.data_priority,ensure_ascii=False,indent=2),json.dumps(train_dataset.data_epoch,ensure_ascii=False,indent=2),json.dumps(train_dataset.get_data_info(),ensure_ascii=False,indent=2))
wandb.log({"data_sample_info": table})
print(json.dumps(train_dataset.data_priority,ensure_ascii=False,indent=2),json.dumps(train_dataset.data_epoch,ensure_ascii=False,indent=2),json.dumps(train_dataset.get_data_info(),ensure_ascii=False,indent=2))
# Out:
# The dataset will save in train_qa_1p_Baichuan2-13B-Base_4096_dataset
# weights [tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., dtype=torch.float64), tensor(32., d ...
# 0it [00:00, ?it/s]wandb: Currently logged in as: lengoctuong23052002 (lengoctuong23052002-fpt-retail) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# creating run (0.4s)
# Tracking run with wandb version 0.20.1
# Run data is saved locally in <code>./train_logs/huatuo2_datapre/wandb/run-20250606_172107-fb4wfuhp</code>
# Syncing run <strong><a href='https://wandb.ai/lengoctuong23052002-fpt-retail/huatuo2_datapre/runs/fb4wfuhp' target="_blank">snowy-water-23</a></strong> to <a href='https://wandb.ai/lengoctuong23052002-fpt-retail/huatuo2_datapre' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/lengoctuong23052002-fpt-retail/huatuo2_datapre' target="_blank">https://wandb.ai/lengoctuong23052002-fpt-retail/huatuo2_datapre</a>
#  View run at <a href='https://wandb.ai/lengoctuong23052002-fpt-retail/huatuo2_datapre/runs/fb4wfuhp' target="_blank">https://wandb.ai/lengoctuong23052002-fpt-retail/huatuo2_datapre/runs/fb4wfuhp</a>
# 1786it [01:38, 18.13it/s]
# all_inputs_ids len 4938
# Canceled future for execute_request message before replies were done
# Canceled future for execute_request message before replies were done.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import numpy as np
for i in took_index:
    print(i)
# Out:
# (205, 'Meidcal_Literature_en')
# (143, 'Meidcal_Literature_en')
# (182, 'Meidcal_Literature_en')
# (28, 'Meidcal_Web_Corpus_en')
# (21, 'Meidcal_Web_Corpus_en')
# (168, 'Meidcal_Literature_en')
# (186, 'Meidcal_Literature_en')
# (121, 'Meidcal_Literature_cn')
# (38, 'Meidcal_Web_Corpus_en')
# (72, 'Meidcal_Web_Corpus_cn')
# (98, 'Meidcal_Web_Corpus_cn')
# (257, 'Meidcal_Encyclopedia_en')
# (76, 'Meidcal_Web_Corpus_cn')
# (129, 'Meidcal_Literature_en')
# (29, 'Meidcal_Web_Corpus_en')
# (68, 'Meidcal_Web_Corpus_cn')
# (352, 'Meidcal_Books_cn')
# (62, 'Meidcal_Web_Corpus_cn')
# (78, 'Meidcal_Web_Corpus_cn')
# (55, 'Meidcal_Web_Corpus_cn')
# (159, 'Meidcal_Literature_en')
# (86, 'Meidcal_Web_Corpus_cn')
# (152, 'Meidcal_Literature_en')
# (34, 'Meidcal_Web_Corpus_en')
# (223, 'Meidcal_Encyclopedia_cn')
# (89, 'Meidcal_Web_Corpus_cn')
# (50, 'Meidcal_Web_Corpus_cn')
# (39, 'Meidcal_Web_Corpus_en')
# (170, 'Meidcal_Literature_en')
# (266, 'Meidcal_Encyclopedia_en')
# (132, 'Meidcal_Literature_en')
# (517, 'Meidcal_Books_en')
# (94, 'Meidcal_Web_Corpus_cn')
# (241, 'Meidcal_Encyclopedia_cn')
# (19, 'Meidcal_Web_Corpus_en')
# (75, 'Meidcal_Web_Corpus_cn')
# (403, 'Meidcal_Books_cn')
# (37, 'Meidcal_Web_Corpus_en')
# (60, 'Meidcal_Web_Corpus_cn')
# (0, 'Meidcal_Web_Corpus_en')
# (340, 'Meidcal_Books_cn')
# (343, 'Meidcal_Books_cn')
# (224, 'Meidcal_Encyclopedia_cn')
# (33, 'Meidcal_Web_Corpus_en')
# (140, 'Meidcal_Literature_en')
# (532, 'Meidcal_Books_en')
# (54, 'Meidcal_Web_Corpus_cn')
# (192, 'Meidcal_Literature_en')
# (48, 'Meidcal_Web_Corpus_cn')
# (196, 'Meidcal_Literature_en')
# (125, 'Meidcal_Literature_en')
# (236, 'Meidcal_Encyclopedia_cn')
# (386, 'Meidcal_Books_cn')
# (183, 'Meidcal_Literature_en')
# (117, 'Meidcal_Literature_cn')
# (238, 'Meidcal_Encyclopedia_cn')
# (149, 'Meidcal_Literature_en')
# (426, 'Meidcal_Books_cn')
# (415, 'Meidcal_Books_cn')
# (57, 'Meidcal_Web_Corpus_cn')
# (249, 'Meidcal_Encyclopedia_cn')
# (171, 'Meidcal_Literature_en')
# (254, 'Meidcal_Encyclopedia_en')
# (127, 'Meidcal_Literature_en')
# (365, 'Meidcal_Books_cn')
# (201, 'Meidcal_Literature_en')
# (234, 'Meidcal_Encyclopedia_cn')
# (32, 'Meidcal_Web_Corpus_en')
# (407, 'Meidcal_Books_cn')
# (74, 'Meidcal_Web_Corpus_cn')
# (36, 'Meidcal_Web_Corpus_en')
# (281, 'Meidcal_Books_cn')
# (269, 'Meidcal_Books_cn')
# (135, 'Meidcal_Literature_en')
# (52, 'Meidcal_Web_Corpus_cn')
# (198, 'Meidcal_Literature_en')
# (58, 'Meidcal_Web_Corpus_cn')
# (131, 'Meidcal_Literature_en')
# (53, 'Meidcal_Web_Corpus_cn')
# (67, 'Meidcal_Web_Corpus_cn')
# (6, 'Meidcal_Web_Corpus_en')
# (24, 'Meidcal_Web_Corpus_en')
# (110, 'Meidcal_Literature_cn')
# (35, 'Meidcal_Web_Corpus_en')
# (27, 'Meidcal_Web_Corpus_en')
# (44, 'Meidcal_Web_Corpus_cn')
# (231, 'Meidcal_Encyclopedia_cn')
# (360, 'Meidcal_Books_cn')
# (61, 'Meidcal_Web_Corpus_cn')
# (328, 'Meidcal_Books_cn')
# (172, 'Meidcal_Literature_en')
# (82, 'Meidcal_Web_Corpus_cn')
# (102, 'Meidcal_Web_Corpus_cn')
# (79, 'Meidcal_Web_Corpus_cn')
# (96, 'Meidcal_Web_Corpus_cn')
# (64, 'Meidcal_Web_Corpus_cn')
# (375, 'Meidcal_Books_cn')
# (290, 'Meidcal_Books_cn')
# (203, 'Meidcal_Literature_en')
# (245, 'Meidcal_Encyclopedia_cn')
# (124, 'Meidcal_Literature_en')
# (115, 'Meidcal_Literature_cn')
# (211, 'Meidcal_Encyclopedia_cn')
# (69, 'Meidcal_Web_Corpus_cn')
# (363, 'Meidcal_Books_cn')
# (63, 'Meidcal_Web_Corpus_cn')
# (101, 'Meidcal_Web_Corpus_cn')
# (15, 'Meidcal_Web_Corpus_en')
# (377, 'Meidcal_Books_cn')
# (193, 'Meidcal_Literature_en')
# (471, 'Meidcal_Books_en')
# (41, 'Meidcal_Web_Corpus_cn')
# (112, 'Meidcal_Literature_cn')
# (499, 'Meidcal_Books_en')
# (73, 'Meidcal_Web_Corpus_cn')
# (410, 'Meidcal_Books_cn')
# (455, 'Meidcal_Books_en')
# (134, 'Meidcal_Literature_en')
# (144, 'Meidcal_Literature_en')
# (104, 'Meidcal_Web_Corpus_cn')
# (14, 'Meidcal_Web_Corpus_en')
# (142, 'Meidcal_Literature_en')
# (175, 'Meidcal_Literature_en')
# (87, 'Meidcal_Web_Corpus_cn')
# (95, 'Meidcal_Web_Corpus_cn')
# (190, 'Meidcal_Literature_en')
# (199, 'Meidcal_Literature_en')
# (272, 'Meidcal_Books_cn')
# (460, 'Meidcal_Books_en')
# (9, 'Meidcal_Web_Corpus_en')
# (258, 'Meidcal_Encyclopedia_en')
# (368, 'Meidcal_Books_cn')
# (81, 'Meidcal_Web_Corpus_cn')
# (176, 'Meidcal_Literature_en')
# (156, 'Meidcal_Literature_en')
# (1, 'Meidcal_Web_Corpus_en')
# (137, 'Meidcal_Literature_en')
# (84, 'Meidcal_Web_Corpus_cn')
# (220, 'Meidcal_Encyclopedia_cn')
# (116, 'Meidcal_Literature_cn')
# (108, 'Meidcal_Literature_cn')
# (165, 'Meidcal_Literature_en')
# (359, 'Meidcal_Books_cn')
# (20, 'Meidcal_Web_Corpus_en')
# (8, 'Meidcal_Web_Corpus_en')
# (509, 'Meidcal_Books_en')
# (97, 'Meidcal_Web_Corpus_cn')
# (480, 'Meidcal_Books_en')
# (107, 'Meidcal_Literature_cn')
# (10, 'Meidcal_Web_Corpus_en')
# (222, 'Meidcal_Encyclopedia_cn')
# (118, 'Meidcal_Literature_cn')
# (123, 'Meidcal_Literature_en')
# (3, 'Meidcal_Web_Corpus_en')
# (136, 'Meidcal_Literature_en')
# (297, 'Meidcal_Books_cn')
# (215, 'Meidcal_Encyclopedia_cn')
# (30, 'Meidcal_Web_Corpus_en')
# (248, 'Meidcal_Encyclopedia_cn')
# (45, 'Meidcal_Web_Corpus_cn')
# (293, 'Meidcal_Books_cn')
# (59, 'Meidcal_Web_Corpus_cn')
# (167, 'Meidcal_Literature_en')
# (472, 'Meidcal_Books_en')
# (307, 'Meidcal_Books_cn')
# (299, 'Meidcal_Books_cn')
# (178, 'Meidcal_Literature_en')
# (179, 'Meidcal_Literature_en')
# (43, 'Meidcal_Web_Corpus_cn')
# (49, 'Meidcal_Web_Corpus_cn')
# (482, 'Meidcal_Books_en')
# (26, 'Meidcal_Web_Corpus_en')
# (16, 'Meidcal_Web_Corpus_en')
# (212, 'Meidcal_Encyclopedia_cn')
# (40, 'Meidcal_Web_Corpus_cn')
# (106, 'Meidcal_Literature_cn')
# (109, 'Meidcal_Literature_cn')
# (120, 'Meidcal_Literature_cn')
# (147, 'Meidcal_Literature_en')
# (128, 'Meidcal_Literature_en')
# (563, 'SFT_data')
# (422, 'Meidcal_Books_cn')
# (525, 'Meidcal_Books_en')
# (210, 'Meidcal_Literature_en')
# (185, 'Meidcal_Literature_en')
# (85, 'Meidcal_Web_Corpus_cn')
# (100, 'Meidcal_Web_Corpus_cn')
# (485, 'Meidcal_Books_en')
# (70, 'Meidcal_Web_Corpus_cn')
# (88, 'Meidcal_Web_Corpus_cn')
# (262, 'Meidcal_Encyclopedia_en')
# (424, 'Meidcal_Books_cn')
# (141, 'Meidcal_Literature_en')
# (206, 'Meidcal_Literature_en')
# (275, 'Meidcal_Books_cn')
# (153, 'Meidcal_Literature_en')
# (105, 'Meidcal_Literature_cn')
# (251, 'Meidcal_Encyclopedia_cn')
# (208, 'Meidcal_Literature_en')
# (228, 'Meidcal_Encyclopedia_cn')
# (65, 'Meidcal_Web_Corpus_cn')
# (207, 'Meidcal_Literature_en')
# (237, 'Meidcal_Encyclopedia_cn')
# (564, 'SFT_data')
# (47, 'Meidcal_Web_Corpus_cn')
# (174, 'Meidcal_Literature_en')
# (155, 'Meidcal_Literature_en')
# (93, 'Meidcal_Web_Corpus_cn')
# (219, 'Meidcal_Encyclopedia_cn')
# (209, 'Meidcal_Literature_en')
# (139, 'Meidcal_Literature_en')
# (103, 'Meidcal_Web_Corpus_cn')
# (397, 'Meidcal_Books_cn')
# (77, 'Meidcal_Web_Corpus_cn')
# (2, 'Meidcal_Web_Corpus_en')
# (194, 'Meidcal_Literature_en')
# (42, 'Meidcal_Web_Corpus_cn')
# (51, 'Meidcal_Web_Corpus_cn')
# (17, 'Meidcal_Web_Corpus_en')
# (92, 'Meidcal_Web_Corpus_cn')
# (5, 'Meidcal_Web_Corpus_en')
# (23, 'Meidcal_Web_Corpus_en')
# (150, 'Meidcal_Literature_en')
# (204, 'Meidcal_Literature_en')
# (246, 'Meidcal_Encyclopedia_cn')
# (4, 'Meidcal_Web_Corpus_en')
# (11, 'Meidcal_Web_Corpus_en')
# (46, 'Meidcal_Web_Corpus_cn')
# (483, 'Meidcal_Books_en')
# (161, 'Meidcal_Literature_en')
# (448, 'Meidcal_Books_cn')
# (500, 'Meidcal_Books_en')
# (296, 'Meidcal_Books_cn')
# (126, 'Meidcal_Literature_en')
# (287, 'Meidcal_Books_cn')
# (119, 'Meidcal_Literature_cn')
# (90, 'Meidcal_Web_Corpus_cn')
# (355, 'Meidcal_Books_cn')
# (542, 'SFT_data')
# (566, 'SFT_data')
# (12, 'Meidcal_Web_Corpus_en')
# (157, 'Meidcal_Literature_en')
# (364, 'Meidcal_Books_cn')
# (267, 'Meidcal_Encyclopedia_en')
# (405, 'Meidcal_Books_cn')
# (130, 'Meidcal_Literature_en')
# (411, 'Meidcal_Books_cn')
# (56, 'Meidcal_Web_Corpus_cn')
# (294, 'Meidcal_Books_cn')
# (435, 'Meidcal_Books_cn')
# (478, 'Meidcal_Books_en')
# (320, 'Meidcal_Books_cn')
# (342, 'Meidcal_Books_cn')
# (133, 'Meidcal_Literature_en')
# (229, 'Meidcal_Encyclopedia_cn')
# (197, 'Meidcal_Literature_en')
# (202, 'Meidcal_Literature_en')
# (393, 'Meidcal_Books_cn')
# (260, 'Meidcal_Encyclopedia_en')
# (18, 'Meidcal_Web_Corpus_en')
# (200, 'Meidcal_Literature_en')
# (571, 'SFT_data')
# (217, 'Meidcal_Encyclopedia_cn')
# (83, 'Meidcal_Web_Corpus_cn')
# (66, 'Meidcal_Web_Corpus_cn')
# (441, 'Meidcal_Books_cn')
# (348, 'Meidcal_Books_cn')
# (22, 'Meidcal_Web_Corpus_en')
# (188, 'Meidcal_Literature_en')
# (138, 'Meidcal_Literature_en')
# (25, 'Meidcal_Web_Corpus_en')
# (273, 'Meidcal_Books_cn')
# (91, 'Meidcal_Web_Corpus_cn')
# (195, 'Meidcal_Literature_en')
# (310, 'Meidcal_Books_cn')
# (306, 'Meidcal_Books_cn')
# (491, 'Meidcal_Books_en')
# (263, 'Meidcal_Encyclopedia_en')
# (80, 'Meidcal_Web_Corpus_cn')
# (520, 'Meidcal_Books_en')
# (7, 'Meidcal_Web_Corpus_en')
# (146, 'Meidcal_Literature_en')
# (394, 'Meidcal_Books_cn')
# (31, 'Meidcal_Web_Corpus_en')
# (547, 'SFT_data')
# (114, 'Meidcal_Literature_cn')
# (510, 'Meidcal_Books_en')
# (282, 'Meidcal_Books_cn')
# (247, 'Meidcal_Encyclopedia_cn')
# (113, 'Meidcal_Literature_cn')
# (497, 'Meidcal_Books_en')
# (191, 'Meidcal_Literature_en')
# (181, 'Meidcal_Literature_en')
# (154, 'Meidcal_Literature_en')
# (384, 'Meidcal_Books_cn')
# (13, 'Meidcal_Web_Corpus_en')
# (302, 'Meidcal_Books_cn')
# (71, 'Meidcal_Web_Corpus_cn')
# (148, 'Meidcal_Literature_en')
# (430, 'Meidcal_Books_cn')
# (283, 'Meidcal_Books_cn')
# (163, 'Meidcal_Literature_en')
# (225, 'Meidcal_Encyclopedia_cn')
# (214, 'Meidcal_Encyclopedia_cn')
# (166, 'Meidcal_Literature_en')
# (164, 'Meidcal_Literature_en')
# (184, 'Meidcal_Literature_en')
# (162, 'Meidcal_Literature_en')
# (280, 'Meidcal_Books_cn')
# (233, 'Meidcal_Encyclopedia_cn')
# (99, 'Meidcal_Web_Corpus_cn')
# (122, 'Meidcal_Literature_cn')
# (400, 'Meidcal_Books_cn')
# (534, 'SFT_data')
# (511, 'Meidcal_Books_en')
# (242, 'Meidcal_Encyclopedia_cn')
# (274, 'Meidcal_Books_cn')
# (356, 'Meidcal_Books_cn')
# (572, 'SFT_data')
# (213, 'Meidcal_Encyclopedia_cn')
# (367, 'Meidcal_Books_cn')
# (508, 'Meidcal_Books_en')
# (418, 'Meidcal_Books_cn')
# (252, 'Meidcal_Encyclopedia_cn')
# (279, 'Meidcal_Books_cn')
# (461, 'Meidcal_Books_en')
# (311, 'Meidcal_Books_cn')
# (227, 'Meidcal_Encyclopedia_cn')
# (189, 'Meidcal_Literature_en')
# (255, 'Meidcal_Encyclopedia_en')
# (239, 'Meidcal_Encyclopedia_cn')
# (300, 'Meidcal_Books_cn')
# (318, 'Meidcal_Books_cn')
# (473, 'Meidcal_Books_en')
# (339, 'Meidcal_Books_cn')
# (528, 'Meidcal_Books_en')
# (486, 'Meidcal_Books_en')
# (158, 'Meidcal_Literature_en')
# (476, 'Meidcal_Books_en')
# (357, 'Meidcal_Books_cn')
# (503, 'Meidcal_Books_en')
# (145, 'Meidcal_Literature_en')
# (529, 'Meidcal_Books_en')
# (345, 'Meidcal_Books_cn')
# (444, 'Meidcal_Books_cn')
# (458, 'Meidcal_Books_en')
# (351, 'Meidcal_Books_cn')
# (270, 'Meidcal_Books_cn')
# (309, 'Meidcal_Books_cn')
# (431, 'Meidcal_Books_cn')
# (216, 'Meidcal_Encyclopedia_cn')
# (413, 'Meidcal_Books_cn')
# (446, 'Meidcal_Books_cn')
# (521, 'Meidcal_Books_en')
# (244, 'Meidcal_Encyclopedia_cn')
# (335, 'Meidcal_Books_cn')
# (180, 'Meidcal_Literature_en')
# (395, 'Meidcal_Books_cn')
# (416, 'Meidcal_Books_cn')
# (187, 'Meidcal_Literature_en')
# (568, 'SFT_data')
# (256, 'Meidcal_Encyclopedia_en')
# (484, 'Meidcal_Books_en')
# (177, 'Meidcal_Literature_en')
# (303, 'Meidcal_Books_cn')
# (353, 'Meidcal_Books_cn')
# (513, 'Meidcal_Books_en')
# (396, 'Meidcal_Books_cn')
# (470, 'Meidcal_Books_en')
# (443, 'Meidcal_Books_cn')
# (493, 'Meidcal_Books_en')
# (488, 'Meidcal_Books_en')
# (160, 'Meidcal_Literature_en')
# (559, 'SFT_data')
# (278, 'Meidcal_Books_cn')
# (474, 'Meidcal_Books_en')
# (169, 'Meidcal_Literature_en')
# (389, 'Meidcal_Books_cn')
# (519, 'Meidcal_Books_en')
# (264, 'Meidcal_Encyclopedia_en')
# (489, 'Meidcal_Books_en')
# (369, 'Meidcal_Books_cn')
# (530, 'Meidcal_Books_en')
# (316, 'Meidcal_Books_cn')
# (463, 'Meidcal_Books_en')
# (451, 'Meidcal_Books_cn')
# (284, 'Meidcal_Books_cn')
# (305, 'Meidcal_Books_cn')
# (427, 'Meidcal_Books_cn')
# (445, 'Meidcal_Books_cn')
# (230, 'Meidcal_Encyclopedia_cn')
# (433, 'Meidcal_Books_cn')
# (373, 'Meidcal_Books_cn')
# (333, 'Meidcal_Books_cn')
# (173, 'Meidcal_Literature_en')
# (551, 'SFT_data')
# (381, 'Meidcal_Books_cn')
# (479, 'Meidcal_Books_en')
# (516, 'Meidcal_Books_en')
# (261, 'Meidcal_Encyclopedia_en')
# (436, 'Meidcal_Books_cn')
# (370, 'Meidcal_Books_cn')
# (392, 'Meidcal_Books_cn')
# (487, 'Meidcal_Books_en')
# (235, 'Meidcal_Encyclopedia_cn')
# (332, 'Meidcal_Books_cn')
# (289, 'Meidcal_Books_cn')
# (498, 'Meidcal_Books_en')
# (323, 'Meidcal_Books_cn')
# (243, 'Meidcal_Encyclopedia_cn')
# (322, 'Meidcal_Books_cn')
# (312, 'Meidcal_Books_cn')
# (429, 'Meidcal_Books_cn')
# (402, 'Meidcal_Books_cn')
# (347, 'Meidcal_Books_cn')
# (391, 'Meidcal_Books_cn')
# (259, 'Meidcal_Encyclopedia_en')
# (417, 'Meidcal_Books_cn')
# (574, 'SFT_data')
# (271, 'Meidcal_Books_cn')
# (390, 'Meidcal_Books_cn')
# (449, 'Meidcal_Books_cn')
# (346, 'Meidcal_Books_cn')
# (354, 'Meidcal_Books_cn')
# (265, 'Meidcal_Encyclopedia_en')
# (226, 'Meidcal_Encyclopedia_cn')
# (277, 'Meidcal_Books_cn')
# (288, 'Meidcal_Books_cn')
# (313, 'Meidcal_Books_cn')
# (358, 'Meidcal_Books_cn')
# (379, 'Meidcal_Books_cn')
# (361, 'Meidcal_Books_cn')
# (111, 'Meidcal_Literature_cn')
# (317, 'Meidcal_Books_cn')
# (385, 'Meidcal_Books_cn')
# (325, 'Meidcal_Books_cn')
# (151, 'Meidcal_Literature_en')
# (456, 'Meidcal_Books_en')
# (546, 'SFT_data')
# (371, 'Meidcal_Books_cn')
# (372, 'Meidcal_Books_cn')
# (253, 'Meidcal_Encyclopedia_en')
# (232, 'Meidcal_Encyclopedia_cn')
# (218, 'Meidcal_Encyclopedia_cn')
# (495, 'Meidcal_Books_en')
# (314, 'Meidcal_Books_cn')
# (341, 'Meidcal_Books_cn')
# (453, 'Meidcal_Books_en')
# (374, 'Meidcal_Books_cn')
# (398, 'Meidcal_Books_cn')
# (442, 'Meidcal_Books_cn')
# (506, 'Meidcal_Books_en')
# (507, 'Meidcal_Books_en')
# (268, 'Meidcal_Books_cn')
# (466, 'Meidcal_Books_en')
# (554, 'SFT_data')
# (502, 'Meidcal_Books_en')
# (454, 'Meidcal_Books_en')
# (292, 'Meidcal_Books_cn')
# (494, 'Meidcal_Books_en')
# (457, 'Meidcal_Books_en')
# (459, 'Meidcal_Books_en')
# (560, 'SFT_data')
# (327, 'Meidcal_Books_cn')
# (558, 'SFT_data')
# (404, 'Meidcal_Books_cn')
# (437, 'Meidcal_Books_cn')
# (298, 'Meidcal_Books_cn')
# (439, 'Meidcal_Books_cn')
# (362, 'Meidcal_Books_cn')
# (526, 'Meidcal_Books_en')
# (477, 'Meidcal_Books_en')
# (467, 'Meidcal_Books_en')
# (419, 'Meidcal_Books_cn')
# (552, 'SFT_data')
# (401, 'Meidcal_Books_cn')
# (250, 'Meidcal_Encyclopedia_cn')
# (492, 'Meidcal_Books_en')
# (465, 'Meidcal_Books_en')
# (286, 'Meidcal_Books_cn')
# (501, 'Meidcal_Books_en')
# (557, 'SFT_data')
# (577, 'SFT_data')
# (469, 'Meidcal_Books_en')
# (515, 'Meidcal_Books_en')
# (481, 'Meidcal_Books_en')
# (440, 'Meidcal_Books_cn')
# (350, 'Meidcal_Books_cn')
# (518, 'Meidcal_Books_en')
# (425, 'Meidcal_Books_cn')
# (387, 'Meidcal_Books_cn')
# (221, 'Meidcal_Encyclopedia_cn')
# (523, 'Meidcal_Books_en')
# (330, 'Meidcal_Books_cn')
# (434, 'Meidcal_Books_cn')
# (336, 'Meidcal_Books_cn')
# (295, 'Meidcal_Books_cn')
# (326, 'Meidcal_Books_cn')
# (240, 'Meidcal_Encyclopedia_cn')
# (452, 'Meidcal_Books_en')
# (540, 'SFT_data')
# (468, 'Meidcal_Books_en')
# (301, 'Meidcal_Books_cn')
# (527, 'Meidcal_Books_en')
# (556, 'SFT_data')
# (349, 'Meidcal_Books_cn')
# (450, 'Meidcal_Books_cn')
# (462, 'Meidcal_Books_en')
# (344, 'Meidcal_Books_cn')
# (366, 'Meidcal_Books_cn')
# (285, 'Meidcal_Books_cn')
# (276, 'Meidcal_Books_cn')
# (428, 'Meidcal_Books_cn')
# (537, 'SFT_data')
# (524, 'Meidcal_Books_en')
# (447, 'Meidcal_Books_cn')
# (432, 'Meidcal_Books_cn')
# (570, 'SFT_data')
# (376, 'Meidcal_Books_cn')
# (512, 'Meidcal_Books_en')
# (420, 'Meidcal_Books_cn')
# (475, 'Meidcal_Books_en')
# (490, 'Meidcal_Books_en')
# (561, 'SFT_data')
# (496, 'Meidcal_Books_en')
# (562, 'SFT_data')
# (315, 'Meidcal_Books_cn')
# (412, 'Meidcal_Books_cn')
# (338, 'Meidcal_Books_cn')
# (543, 'SFT_data')
# (399, 'Meidcal_Books_cn')
# (308, 'Meidcal_Books_cn')
# (319, 'Meidcal_Books_cn')
# (514, 'Meidcal_Books_en')
# (406, 'Meidcal_Books_cn')
# (505, 'Meidcal_Books_en')
# (409, 'Meidcal_Books_cn')
# (383, 'Meidcal_Books_cn')
# (504, 'Meidcal_Books_en')
# (329, 'Meidcal_Books_cn')
# (414, 'Meidcal_Books_cn')
# (378, 'Meidcal_Books_cn')
# (304, 'Meidcal_Books_cn')
# (533, 'SFT_data')
# (380, 'Meidcal_Books_cn')
# (321, 'Meidcal_Books_cn')
# (536, 'SFT_data')
# (382, 'Meidcal_Books_cn')
# (324, 'Meidcal_Books_cn')
# (331, 'Meidcal_Books_cn')
# (334, 'Meidcal_Books_cn')
# (423, 'Meidcal_Books_cn')
# (408, 'Meidcal_Books_cn')
# (388, 'Meidcal_Books_cn')
# (464, 'Meidcal_Books_en')
# (291, 'Meidcal_Books_cn')
# (421, 'Meidcal_Books_cn')
# (569, 'SFT_data')
# (531, 'Meidcal_Books_en')
# (522, 'Meidcal_Books_en')
# (438, 'Meidcal_Books_cn')
# (567, 'SFT_data')
# (535, 'SFT_data')
# (544, 'SFT_data')
# (553, 'SFT_data')
# (565, 'SFT_data')
# (538, 'SFT_data')
# (337, 'Meidcal_Books_cn')
# (575, 'SFT_data')
# (555, 'SFT_data')
# (573, 'SFT_data')
# (576, 'SFT_data')
# (545, 'SFT_data')
# (541, 'SFT_data')
# (539, 'SFT_data')
# (549, 'SFT_data')
# (548, 'SFT_data')
# (550, 'SFT_data')

# %%
print(tokenizer.decode(all_inputs_ids[1]))
# Out:
#  <问>：APOA5基因与心血管疾病的关联是什么？有何具体机制？
# <答>：APOA5基因与心血管疾病的关联是很密切的。APOA5基因位于人类11号染色体上，编码的蛋白质被称为载脂蛋白A-V(apoA-V)，主要在肝脏中表达。apoA-V是血浆甘油三酯水平的重要决定因素，而高血浆甘油三酯水平是冠状动脉疾病的主要风险因素之一。
#
# 研究表明，apoA-V通过与LDL-R基因家族受体相互作用，影响脂蛋白代谢。apoA-V是几种脂蛋白分子的组成部分，包括VLDL、HDL和乳糜微粒。APOA5基因与代谢综合征密切相关，由此也可看出其与心血管疾病的关联。
#
# 此外，APOA5基因中也包含27个与冠状动脉疾病增加风险有关的SNP（单核苷酸多态性）。
#
# 值得一提的是，APOA5基因的发现是通过对人类和小鼠DNA进行比较测序得到的。APOA5基因与其他载脂蛋白基因(APOA1、APOC3、APOA4)位于同一基因簇中，位于人类11号染色体的11q23位置。通过建立两种小鼠模型(APoA5转基因和APoA5敲除)，证实了该基因在血浆甘油三酯水平决定中的重要作用。转基因小鼠的血浆甘油三酯水平较低，而敲除小鼠的血浆甘油三酯水平较高，但两者的血浆胆固醇水平均保持不变。另外，还有一组荷兰研究人员描述了这个相同的基因，将其与肝脏再生的早期阶段相关联，但没有意识到它在血浆甘油三酯水平决定中的重要作用。
#
# 蛋白质结构方面，APOA5基因包含4个外显子和3个内含子，基因位于11号染色体的11q23区域，靠近载脂蛋白基因簇。apoA5蛋白属于载脂蛋白A1/A4/E家族，包含2个螺旋卷曲结构域，整体上预测apoA5约有60%的α-螺旋结构。
#
# 综上所述，APOA5基因通过调节血浆甘油三酯水平等机制与心血管疾病密切相关。</s> <问>：夏季少吃冷饮以防月经不准
# <答>：夏季少吃冷饮确实可以起到一定的作用来预防月经不准。在中医理论中，女性的月经和子宫是寒热之间的平衡状态，而冷饮属于寒性食物，会导致体内寒气增加，从而影响子宫的温度平衡，导致月经不调。因此，夏季少吃冷饮是为了维持体内的热量平衡，有助于月经的规律。
#
# 除了少吃冷饮外，还有其他一些方法可以帮助调节月经不准的情况。首先，建议你定期进行适量的运动，例如散步、瑜伽等，有助于提高身体的新陈代谢和血液循环，帮助调节月经。此外，保持良好的生活规律，避免过度劳累和精神紧张，也可以帮助稳定月经周期。
#
# 如果你发现自己的月经一直不规律或伴有其他症状，建议你咨询医生进行进一步的检查和治疗。医生可以根据您的具体情况，通过中医或西医的方法来帮助您调节月经。同时，医生也可以根据您的体质和症状给予相应的饮食建议，帮助您更好地调理身体。
#
# 总之，夏季少吃冷饮是有助于预防月经不准的，但也要注意综合调理，保持良好的生活习惯和饮食规律，如果有需要可以咨询医生以获取更专业的建议和治疗方案。</s> <问>：在南非实施基因型MTBDRplus能否缩短多重耐药结核治疗的时间？
# <答>：基因型MTBDRplus在南非能够缩短多重耐药结核治疗的时间。使用MTBDRplus使得开始进行多重耐药结核治疗的时间大大缩短。然而，由于实验室运营方面的延迟，包括在进行MTBDRplus测试之前需要进行涂片和培养阳性检验，导致向诊所报告耐药性检测结果的时间延迟超过1周。此外，一旦报告了多重耐药结核，与患者联系和开始治疗的延迟需要改善临床基础设施。</s> <问>：如何通过基因组学在临床护理中应用基因组技术，进一步提高科学教育的重要性，并对未来有何期望？
# <答>：基因组学在临床护理中的应用，可以通过基因组技术进一步提高科学教育的重要性，并在未来进一步推动医学的发展。基因组学涉及到分析一个有机体所有的DNA，它可以通过对基因组的测序来了解DNA的编码信息。在人类的基因组中，有60亿个“字母”组成。每个人之间的差异大约在几百万个DNA字母之间。这些差异决定了我们眼睛的颜色、是否对乳糖耐受，以及是否携带某种疾病。
#
# 随着对基因组的研究和信息解读的深入，我们也能够对个体的健康做出一些准确的预测。已经有一些疾病可以通过基因检测来确定，比如亨廷顿病、唐氏综合症、脆性X综合症和镰刀形贫血等。还有一些疾病存在基因风险因素，比如BRCA1基因的特定突变会大大增加患乳腺癌的风险，但并不意味着一定会患上癌症。
#
# 此外，一些研究还发现了与一些复杂疾病（如高血压、阿尔茨海默病和心脏病）风险增加相关的基因变异。
#
# 将基因组技术应用于临床护理中，可以帮助医生更好地了解患者的遗传背景和潜在风险，以个性化的方式进行治疗，并制定更有效的预防策略。此外，基因组技术还可以用于药物研发，帮助开发更精确和个体化的治疗方法。
#
# 这些重要的应用领域进一步强调了在科学教育中加强基因组学的重要性。通过科学教育，我们可以增加公众对基因组学的认知，并提高基因组技术在临床护理中的应用水平。
#
# 面对未来，我们期望基因组学在临床护理中的应用能够不断发展和创新。随着技术的进步，我们可以预见，基因组技术将会更加便捷、准确，并在更多的疾病预防、诊断和治疗中发挥作用。</s> <问>：子宫肥大就是腺肌症吗 子宫肥大和腺肌症的区别介绍
# <答>：子宫肥大并不等同于腺肌症，它们有着一些区别。子宫肥大是指子宫的均匀性增大，而腺肌症是指由子宫内膜腺体或者是间质侵入到子宫的肌层所引发的子宫病变。虽然子宫肥大和腺肌症都是常见的妇科疾病，并且有类似的症状，但它们的病因、临床表现和治疗方式有所不同。
#
# 首先，子宫肥大和腺肌症的病因不同。子宫肥大常见的原因包括卵巢功能障碍、子宫炎症以及子宫肌层弹性纤维组织增生等。而腺肌症的致病原因尚不明确，一般认为是由于子宫粘膜下层的缺乏，以及子宫内膜腺体和间质侵入到子宫内的肌层所引起的。
#
# 其次，子宫肥大和腺肌症的临床表现也有不同。子宫肥大患者常出现月经持续时间长，月经周期延长，但月经量不多。通过妇科B超检查，可以看到子宫呈均匀性增大，质地较硬。腺肌症患者常出现月经不调，如经量增加、月经前后仍有出血、痛经等症状。在妇科检查下，可触及子宫呈均匀增大、球形，并伴有硬结。
#
# 最后，子宫肥大和腺肌症的治疗方式也不同。对于子宫肥大，一般采取保守治疗，并考虑给予适量的雄激素来减少出血。如果保守治疗无效，才考虑全子宫切除术。而腺肌症的治疗方法有多种选择，需要根据患者的年龄、症状和生育特点来确定，手术和药物治疗是常见的治疗方式。
#
# 尽管子宫肥大和腺肌症有一些相似之处，但它们是两种完全不同的疾病。无论是子宫肥大还是腺肌症，如果不及时采取适当的治疗方案，有针对性地进行治疗，都可能引发多种并发症，严重情况下还可能导致女性不孕不育。</s> <问>：有关脑血流描述错误的是什么？
# <答>：脑血流描述错误包括以下情况：当血压下降或血供不足时，脑组织的局部代谢产物会积聚，这可能引起血管收缩，导致脑血流量减少。这种情况可能会导致脑部的缺氧和代谢产物的堆积，从而进一步影响脑功能。所以，正确的描述应该是血压下降、血供不足导致脑血流量减少，而不是增加。脑血流的减少可能会引发一系列神经系统疾病，如脑卒中、脑血栓形成等，因此我们应该重视脑血流的正常调节和保持。</s> <问>：儿童患了蛛网膜囊肿羊羔疯有什么危害
# <答>：蛛网膜囊肿羊羔疯是一种癫痫病，常见于儿童和青少年。这种疾病的危害主要体现在以下几个方面：
#
# 1. 羊羔疯发作：蛛网膜囊肿羊羔疯的主要临床表现是羊羔疯发作以及头痛等症状。如果不及时治疗，羊羔疯可能会反复发作，给儿童身体和心理带来很大的不良影响。
#
# 2. 影响儿童身体发育：蛛网膜囊肿羊羔疯可能会影响儿童的身体发育，包括生长发育和智力发育。由于儿童的身体发育尚未完全成熟，蛛网膜囊肿羊羔疯会对其身体各个方面的发育产生不利影响。
#
# 3. 忽视病情：蛛网膜囊肿羊羔疯的症状通常不明显，容易被家长所忽视。如果家长没有及时发现并引起重视，可能延误了治疗时机，使病情进一步恶化。
#
# 对于蛛网膜囊肿羊羔疯的治疗，现代医学已经有了很多方法，但是某些治疗手段可能会留下一些后遗症。因此，对于儿童如有抽搐、头痛等症状，应及时就医寻求专业的诊断和治疗。
#
# 总之，蛛网膜囊肿羊羔疯对儿童的危害是存在的，包括羊羔疯发作和身体发育方面的影响。为了保障儿童的健康，家长应积极关注儿童的身体状况，发现异常及时就医。</s> <问>：血压高血脂正常范围是多少 一招教你看懂三高数值
# <答>：血压高血脂正常范围在不同年龄段有所不同。通常成年人的正常血压范围是舒张压小于等于90，收缩压小于等于140。而对于老年人来说，血压稍微偏高也可以被接受。如果老年人的血压值在140~90或者160~95之间，还不能确定是否出现了高血压问题，这只是一个临界点，需要多次进行检查确诊。老年人如果能够将血压控制在120~80左右，就是最理想的范围。过高或过低的血压都不好，过低的血压被定义为低血压，一般小于100~60。血压过低也需要及时调节。
#
# 对于血脂正常范围，一般认为总胆固醇在5.2 mmol/L以下，甘油三酯在1.7 mmol/L以下，LDL（低密度脂蛋白胆固醇）在3.4 mmol/L以下是正常的。而高密度脂蛋白胆固醇（HDL）在1.0 mmol/L以上被认为是正常的。这些数值可以作为参考，但最好根据个人情况结合医生的建议进行判断。
#
# 对于老年人来说，如果有高血压或高血脂问题，还需要注意以下几点：饮食上可采用少量多餐的方式，每餐饭量适中，避免一次性吃得太多。晚餐尽量少吃，减少身体内脂肪堆积。此外，戒烟戒酒、适当进行运动，并定期进行检测也很重要。</s> <问>：下山注意保护膝盖 4招应对肌肉酸痛
# <答>：爬山后的肌肉酸痛是很常见的现象，下山时要注意保护膝盖，以下提供几个应对肌肉酸痛的方法。首先，下山速度一定要慢，小心行走，尽量不要跑下山，以免对膝盖造成伤害。特别是年纪较大或腿脚不灵活的人，最好使用登山杖来辅助下山。其次，在爬山之前要准确评估自己的体力，选择合适的登山鞋，确保舒适并提供防滑功能。此外，在登山准备活动前适当减轻负担，避免过量负荷。当然，平时的锻炼对于减轻肌肉酸痛也很重要。对于爬完山后出现肌肉酸痛的情况，可以进行腿部按摩，以加快肌肉中乳酸的分解，缓解酸痛感。另外，使用热毛巾对腿部肌肉进行热敷，能够促进血液循环，缓解肌肉酸痛。最后，运动后适当进行肌肉拉伸，也有助于加速乳酸分解，减轻肌肉酸痛。为了预防爬山后的腿疼，建议平时增加运动锻炼，增强体质，保护好膝关节。在运动前，进行适当的热身活动也是非常重要的。</s> <问>：在困难直接喉镜检查中，头部和颈部的抬高是否可以改善声门的视野？
# <答>：在困难的直接喉镜检查中，头部和颈部的抬高可以改善声门的视野。通过将头部和颈部抬高超过正常的嗅气位，可以使声门结构更好地可见，从而提高气管插管的成功率。这种姿势被称为"Ramped Position"，通过将患者的头部抬高至30°，使得喉部与气管更加直线化，提供更好的可视化效果。此外，还可以通过放置垫子或枕头在患者的背下方，进一步抬高头部和颈部，从而进一步改善视野。这一方法在困难直接喉镜检查中被广泛使用，并且已经被证明可以提高气管插管的成功率。因此，在进行困难直接喉镜检查时，我们建议将头部和颈部抬高以改善声门的视野。但是请注意，具体的姿势和抬高幅度应根据每个患者的情况进行调整，以确保安全和有效性。</s> <问>：护手美白的几个小妙招
# <答>：护手美白是许多人关注的话题，下面我给您分享几个小妙招，希望对您有所帮助。
#
# 首先，要做好日常的手部清洁工作。经常用温水和温和的洗手液洗手，避免使用过于刺激的清洁剂，洗完后记得用干净的毛巾轻轻擦干。
#
# 其次，手部保湿十分重要。每天为手部涂抹适合您的手部保湿霜或护手霜，特别是在洗手后或遇到干燥的环境时，要及时补充水分。推荐选择含有保湿成分如甘油、玻尿酸的产品，能够滋润肌肤，改善干燥。
#
# 另外，给手部进行按摩也是促进血液循环、改善皮肤肤色的有效方法。您可以使用一些天然的水果或植物油，如柠檬、椰子油等，在手部轻轻按摩，能够增加血液循环，使皮肤得到充分的营养，提亮肤色。
#
# 此外，保护手部免受紫外线的侵害也是护手美白的重要一环。在户外活动时要做好防晒工作，涂抹适合手部的防晒霜，避免晒伤和色斑的产生。
#
# 最后，饮食方面也影响着手部的美白效果。保证摄入足够的优质蛋白质、维生素A、B、D等营养物质，可以从食物中获取对手部健康有益的营养。例如鸡蛋、燕窝等富含胶原蛋白的食物，以及一些富含维生素的水果和蔬菜，如胡萝卜、菠菜等。
#
# 综上所述，保持手部的清洁、保湿，适时按摩，防晒以及合理饮食，这些都是护手美白的小妙招。希望对您有所帮助，祝您拥有美丽健康的双手！</s> <问>：什么因素导致感染性炎症时食物摄入减少？
# <答>：感染性炎症导致食物摄入减少的因素有多个。研究表明，食物摄入减少与迷走神经和脑干途径有关，它们在饮食调节和免疫对脑部的传递方面起着重要作用。在感染性炎症时，迷走神经传入核团和投射到副延髓核的神经元释放谷氨酸。因此，研究人员对脑干谷氨酸受体在健康动物自发性摄食和外周给予细菌脂多糖或白细胞介素-1β后的疾病关联性减食中的作用进行了研究。研究发现，脑干I和II型代谢型谷氨酸受体拮抗剂增加了生理盐水和脂多糖处理的大鼠的食物摄入量，但不影响离子型谷氨酸受体。在这些动物中，副延髓核的细胞激活标记物c-Fos的表达以及脂多糖诱导的区域后壁上核前部背侧脑神经核的激活被抑制。I型代谢型谷氨酸受体在这些结构中不与c-Fos或调节胃功能的神经元共定位。然而，在这些结构中，研究人员发现了I型代谢型谷氨酸受体存在于调节胃的脉冲放大神经元上，以及三叉神经和舌下神经运动神经元上。总之，研究结果显示，在外周给予细菌脂多糖后，脑干代谢型谷氨酸受体减少食物摄入，并激活副延髓核和区域前壁上核前部背侧的神经核。这些发现也揭示了可能介导这些效应的脑干I型代谢型谷氨酸受体依赖性环路。</s> <问>：什么是髋关节或膝关节置换手术的替代选择？哪些人适合进行髋关节或膝关节置换手术？
# <答>：髋关节或膝关节置换手术的替代选择主要包括非手术治疗方法和其他手术选择。非手术治疗方法包括使用抗炎药物、减肥、物理治疗、类固醇注射、跟垫、减压支具、葡萄糖胺注射等。此外，还有一些辅助疗法，如针灸、按摩、瑜伽等，可以帮助减轻症状。
#
# 适合进行髋关节或膝关节置换手术的人群包括以下几种情况：
# 1. 经过了所有非手术治疗，并获得了较小的缓解效果。
# 2. 髋关节或膝关节因关节炎而持续疼痛。
# 3. 骨头之间的摩擦和软骨磨损导致不适感。
# 4. 关节松动或不稳定导致摔倒等问题。
# 5. 在日常生活中行走、爬楼梯或弯腰等方面存在困难。
# 6. 由于剧烈的疼痛无法入睡。
# 髋关节或膝关节置换手术是由患者选择进行的选择性手术，可以改善关节功能和生活质量，并减轻疼痛。但请记住，并非所有患者都适合手术。对于早期关节炎较轻的患者，手术不是首选，最好先尝试其他治疗方法。另外，患有严重心脏或肺部疾病的患者手术后可能会暂时加重病情，因此需要对患者进行彻底的评估。肌肉无力疾病（如帕金森病）和出血倾向的患者也不适合进行髋关节或膝关节置换手术。
#
# 希望以上信息对您有帮助。</s> <问>：尼群地平片是什么药物？
# <答>：尼群地平片是一种治疗高血压的药物，其主要成份为尼群地平。它属于钙通道阻滞剂类药物，通过抑制血管平滑肌内钙离子内流，起到扩张全身血管的作用，从而降低血压。使用尼群地平片的成人常见用量为开始一次口服10mg，每日1次，根据情况可调整为20mg，每日2次。使用该药物时需要注意以下几点：
# 1. 少数病例可能出现血碱性磷酸酶增高。
# 2. 肝功能不全时血药浓度可增高，肾功能不全时对药代动力学影响小，慎用本品。
# 3. 大多数患者服用此药后仅有轻度低血压反应，但个别患者可出现严重的体循环低血压症状。在初期调整药量期间或者增加药物用量的时候，特别是合用β-受体阻滞剂时，需定期测量血压。
# 4. 少数患者在服用此药或增加剂量期间，心绞痛或心肌梗死的发生率增加。有冠状动脉狭窄的患者风险更大，服用本品期间需定期作心电图。
# 5. 少数接受β-受体阻滞剂的患者在开始服用此药后可发生心力衰竭，有主动脉狭窄的患者这种危险性更大。
#
# 需要注意的是，本品对于对尼群地平片过敏者以及严重主动脉瓣狭窄患者禁用。</s> <问>：高钾血症可以吃鸡蛋吗
# <答>：高钾血症是一种体内血液中钾离子浓度高于正常范围的疾病。在饮食方面，患者需要注意摄入含钾量低的食物，以避免进一步增加血液中的钾离子浓度。鸡蛋是一种钾含量不高的食物，因此高钾血症患者是可以吃鸡蛋的。
#
# 鸡蛋是一种优质的食物，富含蛋白质、维生素和矿物质，并且容易被人体消化吸收。它是一种经济实惠的食物，可以通过多种方式烹饪，比如煮、蒸、煎等。鸡蛋的营养价值高，可以为高钾血症患者提供所需的能量。
#
# 在选择其他食物时，高钾血症患者应该避免食用含钾量高的食物。如香蕉、海带、韭菜、番茄、蘑菇、菠菜、榨菜等都含有较高的钾元素，患者需要避免食用。而一些含铁丰富的食物如动物肝脏、瘦肉等可以多吃，另外苹果、梨和葡萄等水果含钾量相对较低，患者也可以适量摄入。
#
# 需要注意的是，患者在饮食中应保持清淡，减少食盐的摄入量。海鲜虽然富含蛋白质和其他营养物质，但由于其钾含量较高，高钾血症患者应避免食用海鲜。然而，水产品中的鱼类可以作为替代品，如鲫鱼、鲢鱼等营养价值较高的鱼类是可以食用的。
#
# 总而言之，高钾血症患者在选择食物时需要注意钾的摄入量。鸡蛋是一种钾含量不高的食物，患者可以食用以补充能量。同时，他们需要避免食用含钾量高的食物，保持饮食的清淡。</s><unk><unk><unk><unk><unk><unk><unk><unk><unk><unk><unk><unk><unk><unk><unk>

# %%
index = took_index[0][0]

key = train_dataset.keys[train_dataset.pos_key[index]]
sub_index = index % train_dataset.lengths[key]
da = train_dataset.preprocess(train_dataset.data_dict[key][sub_index])
tokenizer.decode(da['input_ids'])
# Out:
# ' <问>：ip给大鼠注射乳清蛋白水解物对其血压和肾脏钠排泄的影响是怎样的？\n<答>：根据目前的研究，我们可以得出关于给大鼠注射乳清蛋白水解物对其血压和肾脏钠排泄的影响的一些结论。这项研究使用具有自发性高血压的大鼠进行实验，并通过腹腔注射乳清蛋白水解物（WPH）来评估其对收缩期动脉血压（SBP）和肾脏钠处理的急性影响。\n\n实验结果显示，在给予0.5 g/kg和1.0 g/kg剂量的WPH后的2小时内，WPH的腹腔注射剂量依赖性降低了高血压大鼠的SBP。与注射0.15 M NaCl（188.5 +/- 9.3 mmHg）相比，注射WPH的SBP分别为176.6 +/- 4.9 mmHg（P = 0.001）和163.8 +/- 5.9 mmHg（P = 0.0018）。\n\n此外，研究还发现，与注射0.15 M NaCl和卡托普利（captopril）治疗的大鼠相比，WPH治疗组的肌酐清除率显著降低（P = 0.0084）。钠的排泄率也明显下降（P = 0.033），而钾的排泄率也显著降低（P = 0.0063）。\n\n需要注意的是，尽管WPH具有体外的血管紧张素转换酶（ACE）抑制活性（IC50 = 0.68 mg/mL），但在注射WPH后，肾小管对钠的重吸收升高，这与ACE抑制的作用相反。\n\n总结来说，该研究结果显示，在给予自发性高血压大鼠注射乳清蛋白水解物后，大鼠的收缩期动脉血压下降，并且肾小管对钠的重吸收增加。</s>'

# %%
index = took_index[1][0]

key = train_dataset.keys[train_dataset.pos_key[index]]
sub_index = index % train_dataset.lengths[key]
da = train_dataset.preprocess(train_dataset.data_dict[key][sub_index])
tokenizer.decode(da['input_ids'])
# Out:
# ' <问>：什么是自噬，并且它如何影响肿瘤细胞对Apo2L/TRAIL疗法的耐药性？\n<答>：自噬是一种细胞自身进行的清理和再利用过程。在细胞遭受损伤或压力的情况下，自噬可以通过将细胞内部的蛋白质和细胞器降解为基本分子来提供能量和营养。这种过程可以帮助细胞应对压力和维持正常功能。\n\n对于Apo2L/TRAIL疗法，它能够选择性地诱导肿瘤细胞凋亡而不伤害正常细胞，因此备受关注。然而，耐药性是该疗法的一个严重限制因素。研究发现，自噬是在凋亡诱导刺激（包括Apo2L/TRAIL）作用下几乎始终被激活的细胞清理和维持过程。与凋亡不同，自噬可能导致细胞死亡或存活，具体取决于环境因素。\n\n研究已经发现了自噬调控Apo2L/TRAIL诱导凋亡的多种分子机制。此外，自噬是否完成（即完整的自噬通路）可能决定癌细胞的命运，即细胞存活或死亡。因此，针对自噬的治疗策略被视为克服Apo2L/TRAIL耐药性的一种有吸引力的方法。\n\n总结来说，自噬是一种细胞清理和再利用的过程，在Apo2L/TRAIL疗法中起到重要的调节作用。了解自噬与凋亡之间的相互作用及其调控机制，对于预测和克服肿瘤细胞对Apo2L/TRAIL疗法的耐药性具有重要意义。</s>'

# %%
logdata
# Out:
# {'SFT_data_num': 2}
